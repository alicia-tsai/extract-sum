# %%
import sys
sys.path.append('../src')

import numpy as np
import pandas as pd
import data
import utils
from main import extract_summary, report_rouge_scores

# %load_ext autoreload
# %autoreload 2
# Out:
# /usr/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
# Get list of titles, reference summaries, and body text
source_titles, source_refs, source_text = data.get_cnn_data(20)
print(len(source_text))
# Out:
# 20

# %% [markdown]
# ## Summarization

# %%
doc_idx = 3
doc = source_text[doc_idx]
ref = source_refs[doc_idx]
title = source_titles[doc_idx] if source_titles else None

# %%
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
extract_summary(doc, ref, title, report_rouge=True, print_rouge=True, methods=methods, print_summary=True);
# Out:
# Soruce Text: 28 sentences, 144 distinct vocab
# # of selected sentences: 3
# =============== Referecne Text ==============
# the "defeat jihad" ad is displayed in several new york subway stations. jewish and christian groups buy new ads, touting religious tolerance. some are already up; others go up on monday.
# -----
# Word count:31
#
# ========== Extracted summary: First k ==========
# New york  -- jewish and christian groups have unveiled three separate ad campaigns to counter what they claim is hateful speech toward muslims contained within an advertisement posted at some new york city subway stations.
# The new ads tout religious tolerance and offer support to the muslim community.
# "help stop bigotry against our muslim neighbors," reads one.
# -----
# Word count:57
# First_k selection computation time: 0.000
#
# ========== Extracted summary: SMRS ==========
# They are confusing resistance to hatred with actual hatred.".
# Cnn's erinn cawthon contributed to this report.
# Regarding her critics, geller said: "their moral myopia is immense.
# -----
# Word count:26
# SMRS computation time: 0.375
#
# ========== Extracted summary: TextRank ==========
# new york  -- jewish and christian groups have unveiled three separate ad campaigns to counter what they claim is hateful speech toward muslims contained within an advertisement posted at some new york city subway stations.
# the campaigns are in response to a controversial "defeat jihad" ad that is displayed in 10 of the city's more than 400 subway stations.
# "we, as an organization of rabbis want to make it clear to new york and to the u.s. that neither rabbis nor the mainstream jewish community support this dehumanization, but in fact we value partnership with our muslim neighbors and muslim organizations," said rabbi jill jacobs, of rabbis for human rights, one of the three groups behind the new ads.
# Word count: 119
# TextRank computation time: 0.006
#
# ========== Extracted summary: FWSR-BM25 ==========
# New york  -- jewish and christian groups have unveiled three separate ad campaigns to counter what they claim is hateful speech toward muslims contained within an advertisement posted at some new york city subway stations.
# "we, as an organization of rabbis want to make it clear to new york and to the u.s. that neither rabbis nor the mainstream jewish community support this dehumanization, but in fact we value partnership with our muslim neighbors and muslim organizations," said rabbi jill jacobs, of rabbis for human rights, one of the three groups behind the new ads.
# Meanwhile, pamela geller, executive director of the american freedom defense initiative, defended the controversial "defeat jihad" ad, saying there is nothing hateful about it.
# -----
# Word count:119
# FWSR-BM25 computation time: 0.001
#
# ====== Extracted summary: FWSR-SIF ======
# Sentence embedding shape: (28, 300)
# New york  -- jewish and christian groups have unveiled three separate ad campaigns to counter what they claim is hateful speech toward muslims contained within an advertisement posted at some new york city subway stations.
# Defeat jihad.".
# Jacobs described an outpouring of support from individual donors in response to the "defeat jihad" ad, which allowed for the purchase of 20 new ads.
# -----
# Word count:62
# FWSR-SIF computation time: 0.001
#
# =============== ROUGE Scores ===============
#
# first-k
# Overlap 1-gram 			F1: 0.341
# Overlap 1-gram 			Precision: 0.269
# Overlap 1-gram 			Recall: 0.467
# Overlap bi-gram 		F1: 0.140
# Overlap bi-gram 		Precision: 0.107
# Overlap bi-gram 		Recall: 0.200
# Longest Common Subsequence 	F1: 0.280
# Longest Common Subsequence 	Precision: 0.250
# Longest Common Subsequence 	Recall: 0.433
#
# SMRS
# Overlap 1-gram 			F1: 0.073
# Overlap 1-gram 			Precision: 0.080
# Overlap 1-gram 			Recall: 0.067
# Overlap bi-gram 		F1: 0.000
# Overlap bi-gram 		Precision: 0.000
# Overlap bi-gram 		Recall: 0.000
# Longest Common Subsequence 	F1: 0.072
# Longest Common Subsequence 	Precision: 0.080
# Longest Common Subsequence 	Recall: 0.067
#
# TextRank
# Overlap 1-gram 			F1: 0.293
# Overlap 1-gram 			Precision: 0.198
# Overlap 1-gram 			Recall: 0.567
# Overlap bi-gram 		F1: 0.125
# Overlap bi-gram 		Precision: 0.079
# Overlap bi-gram 		Recall: 0.300
# Longest Common Subsequence 	F1: 0.213
# Longest Common Subsequence 	Precision: 0.198
# Longest Common Subsequence 	Recall: 0.567
#
# FWSR-BM25
# Overlap 1-gram 			F1: 0.244
# Overlap 1-gram 			Precision: 0.161
# Overlap 1-gram 			Recall: 0.500
# Overlap bi-gram 		F1: 0.082
# Overlap bi-gram 		Precision: 0.052
# Overlap bi-gram 		Recall: 0.200
# Longest Common Subsequence 	F1: 0.172
# Longest Common Subsequence 	Precision: 0.161
# Longest Common Subsequence 	Recall: 0.500
#
# FWSR-SIF
# Overlap 1-gram 			F1: 0.345
# Overlap 1-gram 			Precision: 0.263
# Overlap 1-gram 			Recall: 0.500
# Overlap bi-gram 		F1: 0.152
# Overlap bi-gram 		Precision: 0.113
# Overlap bi-gram 		Recall: 0.233
# Longest Common Subsequence 	F1: 0.274
# Longest Common Subsequence 	Precision: 0.246
# Longest Common Subsequence 	Recall: 0.467

# %% [markdown]
# ### ROUGE Score

# %%
# %%time
# k=5
# ratio=0.3
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
extract_summary(doc, ref, title, report_rouge=True, rouge_embed=False, 
                methods=methods, print_summary=False, print_rouge=True);
# Out:
# =============== ROUGE Scores ===============
#
# first-k
# Overlap 1-gram 			F1: 0.341
# Overlap 1-gram 			Precision: 0.269
# Overlap 1-gram 			Recall: 0.467
# Overlap bi-gram 		F1: 0.140
# Overlap bi-gram 		Precision: 0.107
# Overlap bi-gram 		Recall: 0.200
# Longest Common Subsequence 	F1: 0.280
# Longest Common Subsequence 	Precision: 0.250
# Longest Common Subsequence 	Recall: 0.433
#
# SMRS
# Overlap 1-gram 			F1: 0.073
# Overlap 1-gram 			Precision: 0.080
# Overlap 1-gram 			Recall: 0.067
# Overlap bi-gram 		F1: 0.000
# Overlap bi-gram 		Precision: 0.000
# Overlap bi-gram 		Recall: 0.000
# Longest Common Subsequence 	F1: 0.072
# Longest Common Subsequence 	Precision: 0.080
# Longest Common Subsequence 	Recall: 0.067
#
# TextRank
# Overlap 1-gram 			F1: 0.293
# Overlap 1-gram 			Precision: 0.198
# Overlap 1-gram 			Recall: 0.567
# Overlap bi-gram 		F1: 0.125
# Overlap bi-gram 		Precision: 0.079
# Overlap bi-gram 		Recall: 0.300
# Longest Common Subsequence 	F1: 0.213
# Longest Common Subsequence 	Precision: 0.198
# Longest Common Subsequence 	Recall: 0.567
#
# FWSR-BM25
# Overlap 1-gram 			F1: 0.244
# Overlap 1-gram 			Precision: 0.161
# Overlap 1-gram 			Recall: 0.500
# Overlap bi-gram 		F1: 0.082
# Overlap bi-gram 		Precision: 0.052
# Overlap bi-gram 		Recall: 0.200
# Longest Common Subsequence 	F1: 0.172
# Longest Common Subsequence 	Precision: 0.161
# Longest Common Subsequence 	Recall: 0.500
#
# FWSR-SIF
# Overlap 1-gram 			F1: 0.345
# Overlap 1-gram 			Precision: 0.263
# Overlap 1-gram 			Recall: 0.500
# Overlap bi-gram 		F1: 0.152
# Overlap bi-gram 		Precision: 0.113
# Overlap bi-gram 		Recall: 0.233
# Longest Common Subsequence 	F1: 0.274
# Longest Common Subsequence 	Precision: 0.246
# Longest Common Subsequence 	Recall: 0.467
# CPU times: user 6.77 s, sys: 459 ms, total: 7.23 s
# Wall time: 10.2 s

# %% [markdown]
# ### Word Embedding ROUGE Score

# %%
# %%time
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
_ = extract_summary(doc, ref, title, report_rouge=True, rouge_embed=True, 
                    methods=methods, print_summary=False, print_rouge=True);
# Out:
# =============== ROUGE Scores ===============
#
# first-k
# Overlap 1-gram 			F1: 0.529
# Overlap 1-gram 			Precision: 0.454
# Overlap 1-gram 			Recall: 0.634
# Overlap bi-gram 		F1: 0.627
# Overlap bi-gram 		Precision: 0.541
# Overlap bi-gram 		Recall: 0.744
# Longest Common Subsequence 	F1: 0.289
# Longest Common Subsequence 	Precision: 0.264
# Longest Common Subsequence 	Recall: 0.634
#
# SMRS
# Overlap 1-gram 			F1: 0.333
# Overlap 1-gram 			Precision: 0.311
# Overlap 1-gram 			Recall: 0.358
# Overlap bi-gram 		F1: 0.497
# Overlap bi-gram 		Precision: 0.489
# Overlap bi-gram 		Recall: 0.505
# Longest Common Subsequence 	F1: 0.274
# Longest Common Subsequence 	Precision: 0.247
# Longest Common Subsequence 	Recall: 0.358
#
# TextRank
# Overlap 1-gram 			F1: 0.541
# Overlap 1-gram 			Precision: 0.471
# Overlap 1-gram 			Recall: 0.634
# Overlap bi-gram 		F1: 0.635
# Overlap bi-gram 		Precision: 0.546
# Overlap bi-gram 		Recall: 0.759
# Longest Common Subsequence 	F1: 0.254
# Longest Common Subsequence 	Precision: 0.235
# Longest Common Subsequence 	Recall: 0.634
#
# FWSR-BM25
# Overlap 1-gram 			F1: 0.496
# Overlap 1-gram 			Precision: 0.430
# Overlap 1-gram 			Recall: 0.586
# Overlap bi-gram 		F1: 0.590
# Overlap bi-gram 		Precision: 0.497
# Overlap bi-gram 		Recall: 0.725
# Longest Common Subsequence 	F1: 0.195
# Longest Common Subsequence 	Precision: 0.183
# Longest Common Subsequence 	Recall: 0.586
#
# FWSR-SIF
# Overlap 1-gram 			F1: 0.441
# Overlap 1-gram 			Precision: 0.460
# Overlap 1-gram 			Recall: 0.424
# Overlap bi-gram 		F1: 0.562
# Overlap bi-gram 		Precision: 0.562
# Overlap bi-gram 		Recall: 0.561
# Longest Common Subsequence 	F1: 0.391
# Longest Common Subsequence 	Precision: 0.369
# Longest Common Subsequence 	Recall: 0.424
# CPU times: user 1min 50s, sys: 5.15 s, total: 1min 55s
# Wall time: 1min 58s

# %% [markdown]
# ## ROUGE Score Across Documents

# %%
#k = 5
start = 0
num_articles = 50
#articles = source_text[start : start + num_articles]
#references = source_refs[start : start + num_articles]
#titles = source_titles[start : start + num_articles] if source_titles else None

# %%
# %%time
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
rouge_mean, rouge_median, rouge_std = report_rouge_scores(source_text[start : start + num_articles], 
                                                          source_refs[start : start + num_articles], 
                                                          methods=methods)

index =  ['1-gram F1', '1-gram Precision', '1-gram Recall', 'bi-gram F1', 'bi-gram Precision', 'bi-gram Recall', 
          'longest common F1', 'longest common Precision', 'longest common Recall', 'runtime', 'word count']

print('=' * 22 + ' Mean ' + '=' * 22)
rouge_mean.index = index
display(rouge_mean)

print('=' * 21 + ' Median ' + '=' * 21)
rouge_median.index = index
display(rouge_median)

print('=' * 15 + ' Standard Deviation ' + '=' * 15)
rouge_std.index = index
display(rouge_std)
# Out:
# ====================== Mean ======================
#                             first-k       SMRS   TextRank   FWSR-BM25  \
# 1-gram F1                  0.283970   0.137945   0.287425    0.242064
# 1-gram Precision           0.227541   0.133652   0.221588    0.177811
# 1-gram Recall              0.394770   0.153078   0.428864    0.394148
# bi-gram F1                 0.097530   0.028034   0.094378    0.075563
# bi-gram Precision          0.076988   0.026087   0.071522    0.055265
# bi-gram Recall             0.142758   0.032647   0.150377    0.127484
# longest common F1          0.225830   0.120759   0.221440    0.176691
# longest common Precision   0.205839   0.123724   0.201695    0.160955
# longest common Recall      0.357514   0.141701   0.387897    0.357252
# runtime                    0.000002   0.436260   0.008230    0.000567
# word count                81.220000  44.720000  96.000000  106.380000
#
#                            FWSR-SIF
# 1-gram F1                  0.248199
# 1-gram Precision           0.222999
# 1-gram Recall              0.305252
# bi-gram F1                 0.080262
# bi-gram Precision          0.068473
# bi-gram Recall             0.102090
# longest common F1          0.210841
# longest common Precision   0.206179
# longest common Recall      0.282338
# runtime                    0.162061
# word count                58.660000
# ===================== Median =====================
#                             first-k       SMRS   TextRank   FWSR-BM25  \
# 1-gram F1                  0.290930   0.128543   0.278485    0.238881
# 1-gram Precision           0.221599   0.123476   0.208100    0.160834
# 1-gram Recall              0.405506   0.148171   0.430195    0.385490
# bi-gram F1                 0.093537   0.000000   0.080983    0.063556
# bi-gram Precision          0.069002   0.000000   0.056250    0.042998
# bi-gram Recall             0.137949   0.000000   0.126038    0.120227
# longest common F1          0.230051   0.114698   0.215067    0.167771
# longest common Precision   0.207699   0.121582   0.195652    0.153852
# longest common Recall      0.366029   0.139610   0.376389    0.336413
# runtime                    0.000002   0.419398   0.006719    0.000508
# word count                84.000000  46.000000  96.500000  100.500000
#
#                            FWSR-SIF
# 1-gram F1                  0.246930
# 1-gram Precision           0.220486
# 1-gram Recall              0.317540
# bi-gram F1                 0.066274
# bi-gram Precision          0.056661
# bi-gram Recall             0.097619
# longest common F1          0.201299
# longest common Precision   0.198039
# longest common Recall      0.289898
# runtime                    0.000642
# word count                63.500000
# =============== Standard Deviation ===============
#                                first-k       SMRS   TextRank  FWSR-BM25  \
# 1-gram F1                 9.845820e-02   0.086012   0.095482   0.097050
# 1-gram Precision          9.026630e-02   0.082520   0.089033   0.080336
# 1-gram Recall             1.330593e-01   0.102517   0.123760   0.135846
# bi-gram F1                7.554147e-02   0.047450   0.082232   0.073697
# bi-gram Precision         6.768483e-02   0.046726   0.071468   0.059986
# bi-gram Recall            9.852067e-02   0.055481   0.110424   0.104457
# longest common F1         9.587966e-02   0.079328   0.093527   0.082981
# longest common Precision  8.915276e-02   0.078102   0.086893   0.074514
# longest common Recall     1.357559e-01   0.094515   0.118540   0.128282
# runtime                   3.471427e-07   0.065639   0.004945   0.000274
# word count                2.649097e+01  20.551438  27.642721  34.111517
#
#                            FWSR-SIF
# 1-gram F1                  0.105398
# 1-gram Precision           0.088248
# 1-gram Recall              0.141010
# bi-gram F1                 0.078685
# bi-gram Precision          0.068171
# bi-gram Recall             0.099025
# longest common F1          0.097612
# longest common Precision   0.082571
# longest common Recall      0.133659
# runtime                    0.352435
# word count                22.421070
# CPU times: user 6min 4s, sys: 25.7 s, total: 6min 29s
# Wall time: 9min 7s

# %%
rouge_mean.to_csv('cnn_lexical_rouge_mean_50.csv', index=False)
rouge_median.to_csv('cnn_lexical_rouge_median_50.csv', index=False)
rouge_std.to_csv('cnn_lexical_rouge_std_50.csv', index=False)

# %% [markdown]
# ### Word Embedding ROUGE Score Across Documents

# %%
# %%time
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
rouge_mean_embed, rouge_median_embed, rouge_std_embed = report_rouge_scores(source_text[start : start + num_articles], 
                                                                            source_refs[start : start + num_articles],  
                                                                            rouge_embed=True, methods=methods)

index =  ['1-gram F1', '1-gram Precision', '1-gram Recall', 'bi-gram F1', 'bi-gram Precision', 'bi-gram Recall', 
          'longest common F1', 'longest common Precision', 'longest common Recall', 'runtime', 'word count']

print('=' * 22 + ' Mean ' + '=' * 22)
rouge_mean_embed.index = index
display(rouge_mean_embed)

print('=' * 21 + ' Median ' + '=' * 21)
rouge_median_embed.index = index
display(rouge_median_embed)

print('=' * 15 + ' Standard Deviation ' + '=' * 15)
rouge_std_embed.index = index
display(rouge_std_embed)
# Out:
# ====================== Mean ======================
#                             first-k       SMRS    TextRank   FWSR-BM25  \
# 1-gram F1                  0.499841   0.378085    0.470540    0.480546
# 1-gram Precision           0.461882   0.365669    0.428937    0.437283
# 1-gram Recall              0.547257   0.394984    0.523717    0.535614
# bi-gram F1                 0.636945   0.505537    0.604998    0.605417
# bi-gram Precision          0.589674   0.492692    0.553082    0.547155
# bi-gram Recall             0.697570   0.520793    0.671482    0.680319
# longest common F1          0.340430   0.365028    0.280239    0.251601
# longest common Precision   0.311931   0.402838    0.254733    0.229324
# longest common Recall      0.547257   0.394984    0.523717    0.535614
# runtime                    0.000002   0.436845    0.007695    0.000668
# word count                86.950000  45.250000  109.600000  115.650000
#
#                            FWSR-SIF
# 1-gram F1                  0.458668
# 1-gram Precision           0.431441
# 1-gram Recall              0.493254
# bi-gram F1                 0.591728
# bi-gram Precision          0.558275
# bi-gram Recall             0.633891
# longest common F1          0.370239
# longest common Precision   0.344089
# longest common Recall      0.493254
# runtime                    0.000790
# word count                65.200000
# ===================== Median =====================
#                             first-k       SMRS    TextRank   FWSR-BM25  \
# 1-gram F1                  0.494221   0.381342    0.473110    0.482652
# 1-gram Precision           0.452126   0.361376    0.422266    0.433166
# 1-gram Recall              0.561550   0.400393    0.515746    0.549116
# bi-gram F1                 0.629315   0.500094    0.601829    0.603059
# bi-gram Precision          0.591417   0.482517    0.544572    0.553478
# bi-gram Recall             0.689947   0.520984    0.664814    0.673485
# longest common F1          0.337503   0.352182    0.267124    0.262434
# longest common Precision   0.302335   0.362847    0.244120    0.240334
# longest common Recall      0.561550   0.400393    0.515746    0.549116
# runtime                    0.000002   0.423888    0.007108    0.000539
# word count                88.000000  43.000000  117.000000  116.500000
#
#                            FWSR-SIF
# 1-gram F1                  0.457555
# 1-gram Precision           0.435739
# 1-gram Recall              0.483549
# bi-gram F1                 0.605761
# bi-gram Precision          0.558130
# bi-gram Recall             0.649210
# longest common F1          0.358447
# longest common Precision   0.325771
# longest common Recall      0.483549
# runtime                    0.000679
# word count                65.500000
# =============== Standard Deviation ===============
#                                first-k       SMRS   TextRank  FWSR-BM25  \
# 1-gram F1                 5.050508e-02   0.046411   0.043790   0.043719
# 1-gram Precision          5.225726e-02   0.049203   0.037999   0.037191
# 1-gram Recall             5.838621e-02   0.055099   0.062725   0.061776
# bi-gram F1                5.513818e-02   0.055319   0.043679   0.039450
# bi-gram Precision         6.032339e-02   0.055805   0.045913   0.039787
# bi-gram Recall            7.209614e-02   0.061661   0.061723   0.056037
# longest common F1         8.029498e-02   0.066847   0.070091   0.054276
# longest common Precision  8.307292e-02   0.138389   0.061291   0.046807
# longest common Recall     5.838622e-02   0.055099   0.062725   0.061776
# runtime                   2.759895e-07   0.053441   0.004110   0.000413
# word count                2.575165e+01  17.832204  30.391446  35.515173
#
#                            FWSR-SIF
# 1-gram F1                  0.038598
# 1-gram Precision           0.037311
# 1-gram Recall              0.056969
# bi-gram F1                 0.048694
# bi-gram Precision          0.050774
# bi-gram Recall             0.066814
# longest common F1          0.070457
# longest common Precision   0.074486
# longest common Recall      0.056969
# runtime                    0.000380
# word count                19.709389
# CPU times: user 36min 46s, sys: 1min 57s, total: 38min 43s
# Wall time: 39min 48s

# %%
rouge_mean_embed.to_csv('cnn_semantic_rouge_mean_50.csv', index=False)
rouge_median_embed.to_csv('cnn_semantic_rouge_median_50.csv', index=False)
rouge_std_embed.to_csv('cnn_semantic_rouge_std_50.csv', index=False)

# %% [markdown]
# ## Data

# %%
references[3]
# Out:
# 'chicago wins bid for new george lucas museum. mayor rahm emanuel calls it "a milestone" for his city. lucas says a prime location in chicago was a deciding factor. museum will house lucas\' art collection and movie memorabilia.'
