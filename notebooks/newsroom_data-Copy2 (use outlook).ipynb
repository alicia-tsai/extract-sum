# %%
import sys
sys.path.append('../src')

import numpy as np
import pandas as pd
import data
import utils
from main import extract_summary, report_rouge_scores

# %load_ext autoreload
# %autoreload 2

# %%
# Get list of titles, reference summaries, and body text
outlook_titles, outlook_refs, outlook_text = data.get_outlook_data()
total = len(outlook_text)
print(total)
# Out:
# 38

# %% [markdown]
# ### Summarization
#
# - Summarization algorithms includes:
#     - SMRS (TF-IDF matrix)
#     - Franke-Wolfe (TF-IDF matrix)
#     - Franke-Wolfe (Sentence embeddings matrix)
# - *Matlab* and *Python for matlab engine* is required to run the SMRS method. Remove `'SMRS'` from the `methods` list below if matlab is not installed.
#
# - Main function: `extract_summary()`
#
# ```python
# # Arguments:
# #     - doc: string; article body text
# #     - ref: string; reference summary
# #     - title: string; title of the article
# #     - k: number of extracted examplars
# #     - print_summary: print summary text for each algorithm
# #     - report_rouge: report rouge score (need to pass in ref argument)
# #     - rouge_embed: use word embedding to calculate rouge score
# #     - vectorize_scores: return scores in np.ndarray instead of in a dictionary
# #     - methods: summarization algorithms to be used
# # Return:
# #     - summary: dictionary; extracted summary sentences using each algorithm
# #     - word_count: dictionary; number of words in the extracted summary
# #     - runtime: computation time of each algorithm
# #     - scores: rouge score of each algorithm
#
# summary, word_count, runtime, scores = extract_summary(doc, ref=None, title=None, k=5, print_summary=False,
#                                                        report_rouge=False, print_rouge=True, rouge_embed=False,
#                                                        vectorize_scores=False, methods=['random', 'SMRS', 'tfidf', 'embed']);
#
# ```

# %%
# 9
doc_idx = 0
doc = outlook_text[doc_idx]
ref = outlook_refs[doc_idx]
title = outlook_titles[doc_idx]
print(ref)
# Out:
# from technology and usd stability to emerging markets rebalancing, we review six key market drivers and risks in 2019. keeping inflation under control. us dollar stability. china’s resilience. calmer european politics. emerging markets rebalancing. tech and healthcare innovations. the best of all worlds is a fairly stable usd.

# %%
# k=5
# ratio=0.2
methods = ['first-k', 'SMRS', 'TextRank', 'tfidf', 'embed']
extract_summary(doc, ref, title, report_rouge=False, methods=methods, print_summary=True);
# Out:
# Soruce Text: 30 sentences, 255 distinct vocab
# # of selected sentences: 7
#
# Title: drivers likely to extend the cycle
#
# =============== Referecne Text ==============
# from technology and usd stability to emerging markets rebalancing, we review six key market drivers and risks in 2019. keeping inflation under control. us dollar stability. china’s resilience. calmer european politics. emerging markets rebalancing. tech and healthcare innovations. the best of all worlds is a fairly stable usd.
# -----
# Word count:48
# [3.6249864 4.4029675 5.358628  4.278138  5.0041075 5.015027  3.5632715]
# Similarity score: 143.55397
#
# ========== Extracted summary: First k ==========
# Growth momentum in advanced economies seems strong enough to extend the cycle into 2019 and beyond.
# The more important question for markets is whether inflation will remain as benign as it has been.
# If inflation rises significantly more than markets (and we) currently expect, the us federal reserve (fed) will be seen as being behind the curve.
# Bond yields would further increase significantly, while equities and other risk assets would likely decline substantially.
# Barring an unlikely surge in productivity, wage growth will be the key driver of inflation.
# Gyrations of the usd tend to destabilize the world economy and financial markets.
# Usd strength, as seen in h1 2018, can put severe strain on economies that require cheap dollar funding.
# -----
# Word count:119
# First_k selection computation time: 0.000
# [3.9308214 3.914006  3.564278  4.3238773 4.0106096 3.9426825 3.356555 ]
# Similarity score: 105.777565
#
# ========== Extracted summary: SMRS ==========
# Meanwhile, we believe that italy and the eu will ultimately find a compromise over the country’s budget deficit while reaffirming italy’s euro membership.
# China’s patience is thus likely to be additionally tested.
# The msci world it sector has outperformed the overall ­market by approximately 200% since march 2009. social media, online shopping and ever more elaborate hand-held devices have taken the world by storm.
# If its policymakers proceed cautiously, as in 2018, risks of instability should be limited and the expansion can be extended.
# At the end of 2018, there were indications that internal and external balance was being restored, in part with the support of the international monetary fund.
# Significant usd weakness puts pressure on export champions, such as germany and japan.
# We expect political stresses to calm down to some extent.
# -----
# Word count:133
# SMRS computation time: 0.580
# [3.1795533 3.470921  3.2106426 3.6906574 3.594681  3.3901303 4.02378  ]
# Similarity score: 86.691574
#
# ========== Extracted summary: TextRank ==========
# if inflation rises significantly more than markets (and we) currently expect, the us federal reserve (fed) will be seen as being behind the curve.
# gyrations of the usd tend to destabilize the world economy and financial markets.
# usd strength, as seen in h1 2018, can put severe strain on economies that require cheap dollar funding.
# after 2008, cheap usd funds seduced em, especially corporations, to substantially boost their foreign currency borrowing.
# yet with the costs of usd liquidity rising in 2018 as a result of a more hawkish fed, stresses emerged and some em currencies suffered severe setbacks.
# an important question for investors is whether growth in this sector will remain this strong, with the emergence of new areas of focus such as virtual reality and artificial intelligence.
# a second key sector that is likely to influence the fate of equity markets is healthcare, with investors keeping an eye on gene therapy and other innovative treatments.
# Word count: 156
# TextRank computation time: 0.013
# [3.5700324 3.9426825 3.356555  3.579655  3.3198829 3.809019  3.7764285]
# Diversity score: 92.16194
#
# ========== Extracted summary: Tfidf ==========
# Moreover, after the usa recently renegotiated trade agreements with mexico, canada and south korea, and amid de-escalating trade tensions with europe, the us trade stance towards china could harden further.
# The msci world it sector has outperformed the overall ­market by approximately 200% since march 2009. social media, online shopping and ever more elaborate hand-held devices have taken the world by storm.
# With fed tightening well advanced, and the european central bank as well as the bank of japan gradually catching up, chances are good that the usd will indeed be stable.
# An important question for investors is whether growth in this sector will remain this strong, with the emergence of new areas of focus such as virtual reality and artificial intelligence.
# Meanwhile, we believe that italy and the eu will ultimately find a compromise over the country’s budget deficit while reaffirming italy’s euro membership.
# A second key sector that is likely to influence the fate of equity markets is healthcare, with investors keeping an eye on gene therapy and other innovative treatments.
# Yet with the costs of usd liquidity rising in 2018 as a result of a more hawkish fed, stresses emerged and some em currencies suffered severe setbacks.
# -----
# Word count:200
# Tfidf computation time: 0.885
# [3.4203122 3.2106426 3.266501  3.761189  3.1795533 3.7079804 3.3198829]
# Similarity score: 81.70364
#
# ====== Extracted summary: sentence embeddings ======
# Sentence embedding shape: (30, 300)
# The best of all worlds is a fairly stable usd.
# China’s patience is thus likely to be additionally tested.
# Gyrations of the usd tend to destabilize the world economy and financial markets.
# We expect political stresses to calm down to some extent.
# It also raises the specter of inflation as commodity prices tend to rise sharply in response to a weak usd.
# If its policymakers proceed cautiously, as in 2018, risks of instability should be limited and the expansion can be extended.
# Meanwhile, we believe that italy and the eu will ultimately find a compromise over the country’s budget deficit while reaffirming italy’s euro membership.
# -----
# Word count:105
# Sentence embedding computation time: 0.994
# [3.3850985 3.470921  3.9426825 4.02378   3.5904422 3.6906574 3.1795533]
# Similarity score: 91.863525

# %% [markdown]
# ### ROUGE Score

# %%
# %%time
# k=5
# ratio=0.3
methods = ['first-k', 'SMRS', 'TextRank', 'tfidf', 'embed']
extract_summary(doc, ref, title, report_rouge=True, rouge_embed=False, 
                methods=methods, print_summary=False, print_rouge=True);
# Out:
# =============== ROUGE Scores ===============
#
# first-k
# Overlap 1-gram 			F1: 0.191
# Overlap 1-gram 			Precision: 0.138
# Overlap 1-gram 			Recall: 0.310
# Overlap bi-gram 		F1: 0.000
# Overlap bi-gram 		Precision: 0.000
# Overlap bi-gram 		Recall: 0.000
# Longest Common Subsequence 	F1: 0.141
# Longest Common Subsequence 	Precision: 0.128
# Longest Common Subsequence 	Recall: 0.286
#
# SMRS
# Overlap 1-gram 			F1: 0.132
# Overlap 1-gram 			Precision: 0.091
# Overlap 1-gram 			Recall: 0.238
# Overlap bi-gram 		F1: 0.000
# Overlap bi-gram 		Precision: 0.000
# Overlap bi-gram 		Recall: 0.000
# Longest Common Subsequence 	F1: 0.089
# Longest Common Subsequence 	Precision: 0.082
# Longest Common Subsequence 	Recall: 0.214
#
# TextRank
# Overlap 1-gram 			F1: 0.181
# Overlap 1-gram 			Precision: 0.124
# Overlap 1-gram 			Recall: 0.333
# Overlap bi-gram 		F1: 0.000
# Overlap bi-gram 		Precision: 0.000
# Overlap bi-gram 		Recall: 0.000
# Longest Common Subsequence 	F1: 0.115
# Longest Common Subsequence 	Precision: 0.106
# Longest Common Subsequence 	Recall: 0.286
#
# tfidf
# Overlap 1-gram 			F1: 0.157
# Overlap 1-gram 			Precision: 0.101
# Overlap 1-gram 			Recall: 0.357
# Overlap bi-gram 		F1: 0.000
# Overlap bi-gram 		Precision: 0.000
# Overlap bi-gram 		Recall: 0.000
# Longest Common Subsequence 	F1: 0.092
# Longest Common Subsequence 	Precision: 0.087
# Longest Common Subsequence 	Recall: 0.310
#
# embed
# Overlap 1-gram 			F1: 0.279
# Overlap 1-gram 			Precision: 0.212
# Overlap 1-gram 			Recall: 0.405
# Overlap bi-gram 		F1: 0.108
# Overlap bi-gram 		Precision: 0.078
# Overlap bi-gram 		Recall: 0.174
# Longest Common Subsequence 	F1: 0.223
# Longest Common Subsequence 	Precision: 0.200
# Longest Common Subsequence 	Recall: 0.381
# CPU times: user 9.12 s, sys: 572 ms, total: 9.69 s
# Wall time: 13.1 s

# %% [markdown]
# ### Word Embedding ROUGE Score

# %%
# %%time
_ = extract_summary(doc, ref, title, report_rouge=True, rouge_embed=True, 
                    methods=methods, print_summary=False, print_rouge=True);
# Out:
# =============== ROUGE Scores ===============
#
# first-k
# Overlap 1-gram 			F1: 0.453
# Overlap 1-gram 			Precision: 0.426
# Overlap 1-gram 			Recall: 0.484
# Overlap bi-gram 		F1: 0.606
# Overlap bi-gram 		Precision: 0.569
# Overlap bi-gram 		Recall: 0.649
# Longest Common Subsequence 	F1: 0.238
# Longest Common Subsequence 	Precision: 0.216
# Longest Common Subsequence 	Recall: 0.484
#
# SMRS
# Overlap 1-gram 			F1: 0.407
# Overlap 1-gram 			Precision: 0.373
# Overlap 1-gram 			Recall: 0.448
# Overlap bi-gram 		F1: 0.533
# Overlap bi-gram 		Precision: 0.485
# Overlap bi-gram 		Recall: 0.593
# Longest Common Subsequence 	F1: 0.186
# Longest Common Subsequence 	Precision: 0.171
# Longest Common Subsequence 	Recall: 0.448
#
# TextRank
# Overlap 1-gram 			F1: 0.451
# Overlap 1-gram 			Precision: 0.419
# Overlap 1-gram 			Recall: 0.488
# Overlap bi-gram 		F1: 0.585
# Overlap bi-gram 		Precision: 0.539
# Overlap bi-gram 		Recall: 0.640
# Longest Common Subsequence 	F1: 0.197
# Longest Common Subsequence 	Precision: 0.182
# Longest Common Subsequence 	Recall: 0.488
#
# tfidf
# Overlap 1-gram 			F1: 0.461
# Overlap 1-gram 			Precision: 0.419
# Overlap 1-gram 			Recall: 0.513
# Overlap bi-gram 		F1: 0.586
# Overlap bi-gram 		Precision: 0.526
# Overlap bi-gram 		Recall: 0.663
# Longest Common Subsequence 	F1: 0.153
# Longest Common Subsequence 	Precision: 0.145
# Longest Common Subsequence 	Recall: 0.513
#
# embed
# Overlap 1-gram 			F1: 0.476
# Overlap 1-gram 			Precision: 0.452
# Overlap 1-gram 			Recall: 0.503
# Overlap bi-gram 		F1: 0.597
# Overlap bi-gram 		Precision: 0.537
# Overlap bi-gram 		Recall: 0.674
# Longest Common Subsequence 	F1: 0.295
# Longest Common Subsequence 	Precision: 0.264
# Longest Common Subsequence 	Recall: 0.503
# CPU times: user 2min 13s, sys: 7.44 s, total: 2min 20s
# Wall time: 2min 24s

# %% [markdown]
# ### ROUGE Score Across Documents

# %%
start = 0
num_articles = total
articles = outlook_text[start : start + num_articles]
references = outlook_refs[start : start + num_articles]
titles = outlook_titles[start : start + num_articles]

# %%
# %%time
methods = ['first-k', 'SMRS', 'TextRank', 'tfidf', 'embed']
rouge_mean, rouge_median, rouge_std = report_rouge_scores(articles, references, titles, methods=methods)

index =  ['1-gram F1', '1-gram Precision', '1-gram Recall', 'bi-gram F1', 'bi-gram Precision', 'bi-gram Recall', 
          'longest common F1', 'longest common Precision', 'longest common Recall', 'runtime', 'word count']

print('=' * 22 + ' Mean ' + '=' * 22)
rouge_mean.index = index
display(rouge_mean)

print('=' * 21 + ' Median ' + '=' * 21)
rouge_median.index = index
display(rouge_median)

print('=' * 15 + ' Standard Deviation ' + '=' * 15)
rouge_std.index = index
display(rouge_std)
# Out:
# ====================== Mean ======================
#                              first-k        SMRS    TextRank       tfidf  \
# 1-gram F1                   0.232502    0.149931    0.199017    0.184991
# 1-gram Precision            0.195770    0.126404    0.148699    0.124568
# 1-gram Recall               0.322923    0.210277    0.327309    0.397492
# bi-gram F1                  0.089026    0.029302    0.042815    0.052754
# bi-gram Precision           0.076471    0.028004    0.030624    0.034422
# bi-gram Recall              0.122522    0.037495    0.077674    0.128820
# longest common F1           0.191703    0.120191    0.143767    0.126039
# longest common Precision    0.182406    0.118251    0.131606    0.117464
# longest common Recall       0.302875    0.196088    0.294994    0.377048
# runtime                     0.000003    0.651033    0.016098    1.523646
# word count                133.368421  114.447368  178.500000  255.473684
#
#                               embed
# 1-gram F1                  0.172717
# 1-gram Precision           0.155612
# 1-gram Recall              0.211179
# bi-gram F1                 0.037985
# bi-gram Precision          0.035617
# bi-gram Recall             0.045623
# longest common F1          0.150240
# longest common Precision   0.147717
# longest common Recall      0.199876
# runtime                    1.657964
# word count                92.000000
# ===================== Median =====================
#                             first-k        SMRS    TextRank       tfidf  \
# 1-gram F1                  0.186649    0.146700    0.186349    0.160031
# 1-gram Precision           0.147214    0.108686    0.130770    0.106428
# 1-gram Recall              0.273864    0.218085    0.321157    0.370241
# bi-gram F1                 0.025995    0.000000    0.015331    0.025989
# bi-gram Precision          0.020762    0.000000    0.010652    0.015995
# bi-gram Recall             0.035760    0.000000    0.027047    0.075499
# longest common F1          0.148432    0.103088    0.124335    0.113506
# longest common Precision   0.134380    0.099177    0.117127    0.104356
# longest common Recall      0.251506    0.195745    0.269697    0.355575
# runtime                    0.000002    0.500333    0.011558    1.055535
# word count                98.000000  104.000000  155.500000  210.500000
#
#                               embed
# 1-gram F1                  0.159003
# 1-gram Precision           0.143182
# 1-gram Recall              0.198309
# bi-gram F1                 0.007399
# bi-gram Precision          0.005723
# bi-gram Recall             0.008893
# longest common F1          0.127341
# longest common Precision   0.134322
# longest common Recall      0.190064
# runtime                    1.131383
# word count                87.000000
# =============== Standard Deviation ===============
#                             first-k       SMRS    TextRank       tfidf  \
# 1-gram F1                  0.166804   0.081618    0.090970    0.077202
# 1-gram Precision           0.168905   0.094093    0.078649    0.060811
# 1-gram Recall              0.179870   0.097740    0.121630    0.121196
# bi-gram F1                 0.177629   0.071052    0.066968    0.063413
# bi-gram Precision          0.171480   0.082679    0.048787    0.043653
# bi-gram Recall             0.198261   0.073696    0.117147    0.141643
# longest common F1          0.169890   0.075666    0.081325    0.064593
# longest common Precision   0.167599   0.093570    0.073005    0.057750
# longest common Recall      0.183587   0.093853    0.124269    0.123580
# runtime                    0.000002   0.398444    0.010995    1.030224
# word count                83.791540  69.896426  108.193722  149.098120
#
#                               embed
# 1-gram F1                  0.092767
# 1-gram Precision           0.099622
# 1-gram Recall              0.105304
# bi-gram F1                 0.075105
# bi-gram Precision          0.077862
# bi-gram Recall             0.083254
# longest common F1          0.086909
# longest common Precision   0.096616
# longest common Recall      0.100980
# runtime                    1.154715
# word count                59.217263
# CPU times: user 7min 29s, sys: 24.1 s, total: 7min 54s
# Wall time: 10min 15s

# %% [markdown]
# ### Word Embedding ROUGE Score Across Documents

# %%
# %%time
methods = ['first-k', 'SMRS', 'TextRank', 'tfidf', 'embed']
rouge_mean_embed, rouge_median_embed, rouge_std_embed = report_rouge_scores(articles, references, titles, 
                                                                            rouge_embed=True, methods=methods)

index =  ['1-gram F1', '1-gram Precision', '1-gram Recall', 'bi-gram F1', 'bi-gram Precision', 'bi-gram Recall', 
          'longest common F1', 'longest common Precision', 'longest common Recall', 'runtime', 'word count']

print('=' * 22 + ' Mean ' + '=' * 22)
rouge_mean_embed.index = index
display(rouge_mean_embed)

print('=' * 21 + ' Median ' + '=' * 21)
rouge_median_embed.index = index
display(rouge_median_embed)

print('=' * 15 + ' Standard Deviation ' + '=' * 15)
rouge_std_embed.index = index
display(rouge_std_embed)
# Out:
# ====================== Mean ======================
#                              first-k        SMRS    TextRank       tfidf  \
# 1-gram F1                   0.481999    0.433341    0.479281    0.499118
# 1-gram Precision            0.457178    0.415907    0.443101    0.450556
# 1-gram Recall               0.513401    0.460778    0.526352    0.564357
# bi-gram F1                  0.621983    0.558296    0.613397    0.617496
# bi-gram Precision           0.589588    0.530270    0.568917    0.552695
# bi-gram Recall              0.662353    0.595274    0.668938    0.702454
# longest common F1           0.316720    0.286637    0.257364    0.186777
# longest common Precision    0.301086    0.337702    0.235658    0.174202
# longest common Recall       0.513401    0.460778    0.526352    0.564357
# runtime                     0.000003    0.651631    0.014941    1.510742
# word count                133.368421  114.447368  178.500000  255.473684
#
#                               embed
# 1-gram F1                  0.437908
# 1-gram Precision           0.418294
# 1-gram Recall              0.466481
# bi-gram F1                 0.561111
# bi-gram Precision          0.533321
# bi-gram Recall             0.598023
# longest common F1          0.351993
# longest common Precision   0.402951
# longest common Recall      0.466481
# runtime                    1.661917
# word count                92.000000
# ===================== Median =====================
#                             first-k        SMRS    TextRank       tfidf  \
# 1-gram F1                  0.484466    0.437796    0.478227    0.500027
# 1-gram Precision           0.462095    0.415514    0.426479    0.450967
# 1-gram Recall              0.528486    0.464912    0.539623    0.580349
# bi-gram F1                 0.615191    0.563448    0.601763    0.616251
# bi-gram Precision          0.573377    0.522826    0.556280    0.554532
# bi-gram Recall             0.655332    0.613431    0.674960    0.703219
# longest common F1          0.309494    0.272578    0.236309    0.179876
# longest common Precision   0.278465    0.252493    0.219183    0.169473
# longest common Recall      0.528486    0.464912    0.539624    0.580349
# runtime                    0.000003    0.528548    0.010568    1.064373
# word count                98.000000  104.000000  155.500000  210.500000
#
#                               embed
# 1-gram F1                  0.435741
# 1-gram Precision           0.420579
# 1-gram Recall              0.471025
# bi-gram F1                 0.542669
# bi-gram Precision          0.516982
# bi-gram Recall             0.605674
# longest common F1          0.367091
# longest common Precision   0.335678
# longest common Recall      0.471025
# runtime                    1.139114
# word count                87.000000
# =============== Standard Deviation ===============
#                                first-k       SMRS    TextRank       tfidf  \
# 1-gram F1                 7.187467e-02   0.059663    0.064598    0.063715
# 1-gram Precision          6.985617e-02   0.062838    0.057793    0.054990
# 1-gram Recall             8.387914e-02   0.073862    0.086373    0.089786
# bi-gram F1                8.533493e-02   0.053955    0.053213    0.051586
# bi-gram Precision         8.936941e-02   0.055664    0.048164    0.048750
# bi-gram Recall            9.372008e-02   0.073056    0.075157    0.069321
# longest common F1         1.229452e-01   0.083070    0.090519    0.067733
# longest common Precision  1.284381e-01   0.361400    0.080629    0.059175
# longest common Recall     8.387914e-02   0.073862    0.086373    0.089786
# runtime                   9.636934e-07   0.344737    0.010218    0.978585
# word count                8.379154e+01  69.896426  108.193722  149.098120
#
#                               embed
# 1-gram F1                  0.071156
# 1-gram Precision           0.070948
# 1-gram Recall              0.083054
# bi-gram F1                 0.068628
# bi-gram Precision          0.073327
# bi-gram Recall             0.081407
# longest common F1          0.105399
# longest common Precision   0.356245
# longest common Recall      0.083054
# runtime                    1.161512
# word count                59.217263
# CPU times: user 1h 31min 17s, sys: 4min 37s, total: 1h 35min 55s
# Wall time: 1h 38min 29s
