# %%
import sys
sys.path.append('../src')

import numpy as np
import pandas as pd
import data
import utils
from main import extract_summary, report_rouge_scores

# %load_ext autoreload
# %autoreload 2
# Out:
# /usr/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ## Summarization

# %%
# Get list of titles, reference summaries, and body text
source_titles, source_refs, source_text = data.get_wiki_data(150)
print(len(source_text))
# Out:
# 150

# %%
doc_idx = 0
doc = source_text[doc_idx]
ref = source_refs[doc_idx]
title = source_titles[doc_idx]

# %%
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
extract_summary(doc, ref, title, report_rouge=False, methods=methods, print_summary=True);
# Out:
# Soruce Text: 31 sentences, 300 distinct vocab
# # of selected sentences: 8
#
# Title: How to Be an Organized Artist1
#
# =============== Referecne Text ==============
#  Keep related supplies in the same area. Make an effort to clean a dedicated workspace after every session. Place loose supplies in large clearly visible containers. Use clotheslines and clips to hang sketches photos and reference material. Use every inch of the room for storage especially vertical space. Use chalkboard paint to make space for drafting ideas right on the walls. Purchase a label maker to make your organization strategy semi-permanent. Make a habit of throwing out old excess or useless stuff each month.
# -----
# Word count:84
#
# ========== Extracted summary: First k ==========
#  if you're a photographer, keep all the necessary lens, cords, and batteries in the same quadrant of your home or studio.
# Paints should be kept with brushes, cleaner, and canvas, print supplies should be by the ink, etc.
# Make broader groups and areas for your supplies to make finding them easier, limiting your search to a much smaller area.
# Some ideas include:   essential supplies area -- the things you use every day.
# Inspiration and reference area.
# Dedicated work area .
# Infrequent or secondary supplies area, tucked out of the way.
# ; , this doesn't mean cleaning the entire studio, it just means keeping the area immediately around the desk, easel, pottery wheel, etc.
# -----
# Word count:113
# First_k selection computation time: 0.000
#
# ========== Extracted summary: SMRS ==========
# Clean each night.
# Artists are constantly making new things, experimenting, and making a mess.
# Discard trash or unnecessary materials and wipe down dirty surfaces.
# Don't be sentimental here.
# Dedicated work area .
# This usually has the opposite effect, leading to lost items and uncertainty when cleaning, but an afternoon with a label maker can solve everything.
# Paint over jars or storage equipment, allowing you to relabel them with chalk as your needs change.
# This is a good thing, but only if you set aside time to declutter.
# -----
# Word count:87
# SMRS computation time: 0.405
#
# ========== Extracted summary: TextRank ==========
# Some ideas include:   Essential supplies area -- the things you use every day.
# Infrequent or secondary supplies area, tucked out of the way.; , This doesn't mean cleaning the entire studio, it just means keeping the area immediately around the desk, easel, pottery wheel, etc.
# , As visual people, a lot of artist clutter comes from a desire to keep track of supplies visually instead of tucked out of sight.
# Plastic restaurant squirt bottles for paint, pigment, etc., Simply string up the wires across a wall or along the ceiling and use them to hold essential papers that you don't want to cut or ruin with tacks or tape.
# Cheap and easy, this is also a good way to handle papers and ideas you touch regularly or need to pin up and down for inspiration., Shelving is an artist's best friend and is a cheap and easy way to get more room in your studio or art space.
# You can even use it for smaller areas.
# Instead of spending all of your mental energy looking for or storing things, you can just follow the labels, freeing your mind to think about art., Once a month, do a purge of your studio.
# Word count: 202
# TextRank computation time: 0.007
#
# ========== Extracted summary: FWSR-BM25 ==========
# Cheap and easy, this is also a good way to handle papers and ideas you touch regularly or need to pin up and down for inspiration., shelving is an artist's best friend and is a cheap and easy way to get more room in your studio or art space.
# The upper reaches of the room are often the most under-utilized, but provide vital space for all your tools and materials., turning one wall into a chalkboard gives you a perfect space for ideas, sketches, and planning without requiring extra equipment or space.
# Some ideas, beyond those just mentioned, include:   canvas shoe racks on the back of the door wine racks with cups in each slot to hold pens/pencils.
# Plastic restaurant squirt bottles for paint, pigment, etc., simply string up the wires across a wall or along the ceiling and use them to hold essential papers that you don't want to cut or ruin with tacks or tape.
# It may not be fun at the moment, but it is a lot more fun than spending 30 minutes digging through junk to find the right paint or an old sketch.
# Instead of spending all of your mental energy looking for or storing things, you can just follow the labels, freeing your mind to think about art., once a month, do a purge of your studio.
# If you haven't used it in the last six months there is little chance you'll use it in the next six months.
# , as visual people, a lot of artist clutter comes from a desire to keep track of supplies visually instead of tucked out of sight.
# -----
# Word count:270
# FWSR-BM25 computation time: 0.912
#
# ====== Extracted summary: FWSR-SIF ======
# Sentence embedding shape: (31, 300)
# Don't be sentimental here.
# Paints should be kept with brushes, cleaner, and canvas, print supplies should be by the ink, etc.
# Clean each night.
# Inspiration and reference area.
# Discard trash or unnecessary materials and wipe down dirty surfaces.
# Artists are constantly making new things, experimenting, and making a mess.
# Infrequent or secondary supplies area, tucked out of the way.
# Toss it.
# -----
# Word count:61
# FWSR-SIF computation time: 1.008

# %% [markdown]
# ### ROUGE Score

# %%
# %%time
# k=5
# ratio=0.3
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
extract_summary(doc, ref, title, report_rouge=True, rouge_embed=False, 
                methods=methods, print_summary=False, print_rouge=True);
# Out:
# =============== ROUGE Scores ===============
#
# first-k
# Overlap 1-gram 			F1: 0.237
# Overlap 1-gram 			Precision: 0.209
# Overlap 1-gram 			Recall: 0.273
# Overlap bi-gram 		F1: 0.052
# Overlap bi-gram 		Precision: 0.045
# Overlap bi-gram 		Recall: 0.062
# Longest Common Subsequence 	F1: 0.216
# Longest Common Subsequence 	Precision: 0.198
# Longest Common Subsequence 	Recall: 0.258
#
# SMRS
# Overlap 1-gram 			F1: 0.171
# Overlap 1-gram 			Precision: 0.162
# Overlap 1-gram 			Recall: 0.182
# Overlap bi-gram 		F1: 0.024
# Overlap bi-gram 		Precision: 0.024
# Overlap bi-gram 		Recall: 0.025
# Longest Common Subsequence 	F1: 0.156
# Longest Common Subsequence 	Precision: 0.149
# Longest Common Subsequence 	Recall: 0.167
#
# TextRank
# Overlap 1-gram 			F1: 0.169
# Overlap 1-gram 			Precision: 0.126
# Overlap 1-gram 			Recall: 0.258
# Overlap bi-gram 		F1: 0.007
# Overlap bi-gram 		Precision: 0.005
# Overlap bi-gram 		Recall: 0.012
# Longest Common Subsequence 	F1: 0.140
# Longest Common Subsequence 	Precision: 0.126
# Longest Common Subsequence 	Recall: 0.258
#
# FWSR-BM25
# Overlap 1-gram 			F1: 0.174
# Overlap 1-gram 			Precision: 0.120
# Overlap 1-gram 			Recall: 0.318
# Overlap bi-gram 		F1: 0.029
# Overlap bi-gram 		Precision: 0.019
# Overlap bi-gram 		Recall: 0.062
# Longest Common Subsequence 	F1: 0.112
# Longest Common Subsequence 	Precision: 0.103
# Longest Common Subsequence 	Recall: 0.273
#
# FWSR-SIF
# Overlap 1-gram 			F1: 0.171
# Overlap 1-gram 			Precision: 0.196
# Overlap 1-gram 			Recall: 0.152
# Overlap bi-gram 		F1: 0.029
# Overlap bi-gram 		Precision: 0.034
# Overlap bi-gram 		Recall: 0.025
# Longest Common Subsequence 	F1: 0.149
# Longest Common Subsequence 	Precision: 0.176
# Longest Common Subsequence 	Recall: 0.136
# CPU times: user 9.14 s, sys: 420 ms, total: 9.56 s
# Wall time: 12.5 s

# %% [markdown]
# ### Word Embedding ROUGE Score

# %%
# %%time
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
_ = extract_summary(doc, ref, title, report_rouge=True, rouge_embed=True, 
                    methods=methods, print_summary=False, print_rouge=True);
# Out:
# =============== ROUGE Scores ===============
#
# first-k
# Overlap 1-gram 			F1: 0.461
# Overlap 1-gram 			Precision: 0.451
# Overlap 1-gram 			Recall: 0.471
# Overlap bi-gram 		F1: 0.603
# Overlap bi-gram 		Precision: 0.577
# Overlap bi-gram 		Recall: 0.632
# Longest Common Subsequence 	F1: 0.395
# Longest Common Subsequence 	Precision: 0.361
# Longest Common Subsequence 	Recall: 0.471
#
# SMRS
# Overlap 1-gram 			F1: 0.441
# Overlap 1-gram 			Precision: 0.422
# Overlap 1-gram 			Recall: 0.463
# Overlap bi-gram 		F1: 0.591
# Overlap bi-gram 		Precision: 0.572
# Overlap bi-gram 		Recall: 0.612
# Longest Common Subsequence 	F1: 0.433
# Longest Common Subsequence 	Precision: 0.413
# Longest Common Subsequence 	Recall: 0.463
#
# TextRank
# Overlap 1-gram 			F1: 0.480
# Overlap 1-gram 			Precision: 0.472
# Overlap 1-gram 			Recall: 0.489
# Overlap bi-gram 		F1: 0.598
# Overlap bi-gram 		Precision: 0.559
# Overlap bi-gram 		Recall: 0.643
# Longest Common Subsequence 	F1: 0.265
# Longest Common Subsequence 	Precision: 0.239
# Longest Common Subsequence 	Recall: 0.489
#
# FWSR-BM25
# Overlap 1-gram 			F1: 0.479
# Overlap 1-gram 			Precision: 0.447
# Overlap 1-gram 			Recall: 0.516
# Overlap bi-gram 		F1: 0.590
# Overlap bi-gram 		Precision: 0.536
# Overlap bi-gram 		Recall: 0.656
# Longest Common Subsequence 	F1: 0.211
# Longest Common Subsequence 	Precision: 0.194
# Longest Common Subsequence 	Recall: 0.516
#
# FWSR-SIF
# Overlap 1-gram 			F1: 0.437
# Overlap 1-gram 			Precision: 0.444
# Overlap 1-gram 			Recall: 0.431
# Overlap bi-gram 		F1: 0.581
# Overlap bi-gram 		Precision: 0.594
# Overlap bi-gram 		Recall: 0.568
# Longest Common Subsequence 	F1: 0.471
# Longest Common Subsequence 	Precision: 0.558
# Longest Common Subsequence 	Recall: 0.431
# CPU times: user 2min 23s, sys: 5.97 s, total: 2min 29s
# Wall time: 2min 32s

# %% [markdown]
# ## ROUGE Score Across Documents

# %%
#k = 5
start = 0
num_articles = 50
articles = source_text[start : start + num_articles]
references = source_refs[start : start + num_articles]
titles = source_titles[start : start + num_articles]

# %%
# %%time
#0-30
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
rouge_mean, rouge_median, rouge_std = report_rouge_scores(articles, references, titles, methods=methods)

index =  ['1-gram F1', '1-gram Precision', '1-gram Recall', 'bi-gram F1', 'bi-gram Precision', 'bi-gram Recall', 
          'longest common F1', 'longest common Precision', 'longest common Recall', 'runtime', 'word count']

print('=' * 22 + ' Mean ' + '=' * 22)
rouge_mean.index = index
display(rouge_mean)

print('=' * 21 + ' Median ' + '=' * 21)
rouge_median.index = index
display(rouge_median)

print('=' * 15 + ' Standard Deviation ' + '=' * 15)
rouge_std.index = index
display(rouge_std)
# Out:
# ====================== Mean ======================
#                              first-k        SMRS    TextRank   FWSR-BM25  \
# 1-gram F1                   0.219590    0.184408    0.223726    0.186617
# 1-gram Precision            0.161904    0.137509    0.163806    0.125279
# 1-gram Recall               0.371354    0.299015    0.406868    0.411573
# bi-gram F1                  0.044802    0.031140    0.050067    0.038192
# bi-gram Precision           0.032645    0.023401    0.036790    0.024921
# bi-gram Recall              0.082133    0.050723    0.099299    0.095931
# longest common F1           0.169489    0.141495    0.165720    0.127312
# longest common Precision    0.155097    0.129136    0.154727    0.118921
# longest common Recall       0.356470    0.282078    0.386125    0.393149
# runtime                     0.000003    0.542597    0.012582    1.631641
# word count                190.040000  146.820000  252.980000  298.700000
#
#                             FWSR-SIF
# 1-gram F1                   0.205744
# 1-gram Precision            0.160839
# 1-gram Recall               0.305303
# bi-gram F1                  0.036613
# bi-gram Precision           0.028569
# bi-gram Recall              0.055906
# longest common F1           0.166819
# longest common Precision    0.152973
# longest common Recall       0.292025
# runtime                     1.817936
# word count                128.520000
# ===================== Median =====================
#                              first-k        SMRS    TextRank   FWSR-BM25  \
# 1-gram F1                   0.220893    0.188070    0.212432    0.190310
# 1-gram Precision            0.157519    0.137469    0.144156    0.121388
# 1-gram Recall               0.367155    0.300909    0.425532    0.419022
# bi-gram F1                  0.046208    0.026288    0.048199    0.037009
# bi-gram Precision           0.032105    0.019231    0.031877    0.022408
# bi-gram Recall              0.068590    0.043854    0.093557    0.087714
# longest common F1           0.164087    0.143410    0.149726    0.119146
# longest common Precision    0.148942    0.130360    0.137413    0.113523
# longest common Recall       0.360851    0.277350    0.408249    0.405882
# runtime                     0.000002    0.467901    0.005286    0.880832
# word count                142.500000  125.000000  169.000000  210.000000
#
#                             FWSR-SIF
# 1-gram F1                   0.213526
# 1-gram Precision            0.163370
# 1-gram Recall               0.293546
# bi-gram F1                  0.028726
# bi-gram Precision           0.023016
# bi-gram Recall              0.042424
# longest common F1           0.168534
# longest common Precision    0.151163
# longest common Recall       0.270552
# runtime                     0.936426
# word count                105.500000
# =============== Standard Deviation ===============
#                              first-k        SMRS    TextRank   FWSR-BM25  \
# 1-gram F1                   0.065356    0.057036    0.073427    0.064897
# 1-gram Precision            0.059057    0.050941    0.073562    0.051585
# 1-gram Recall               0.092416    0.082724    0.105215    0.122009
# bi-gram F1                  0.032187    0.026675    0.039846    0.030082
# bi-gram Precision           0.025437    0.020586    0.036040    0.020516
# bi-gram Recall              0.059822    0.046022    0.067058    0.073544
# longest common F1           0.063792    0.053126    0.071924    0.053708
# longest common Precision    0.056111    0.047343    0.067964    0.047764
# longest common Recall       0.086773    0.081356    0.095342    0.116400
# runtime                     0.000001    0.339020    0.015366    2.021912
# word count                171.140873  106.383023  282.990706  268.146247
#
#                             FWSR-SIF
# 1-gram F1                   0.064691
# 1-gram Precision            0.059146
# 1-gram Recall               0.096338
# bi-gram F1                  0.032761
# bi-gram Precision           0.025378
# bi-gram Recall              0.055741
# longest common F1           0.057610
# longest common Precision    0.053691
# longest common Recall       0.093284
# runtime                     2.362582
# word count                100.871847
# CPU times: user 9min 21s, sys: 26.3 s, total: 9min 47s
# Wall time: 12min 42s

# %%
rouge_mean.to_csv('wiki_lexical_rouge_mean_50.csv', index=False)
rouge_median.to_csv('wiki_lexical_rouge_median_50.csv', index=False)
rouge_std.to_csv('wiki_lexical_rouge_std_50.csv', index=False)

# %% [markdown]
# ### Word Embedding ROUGE Score Across Documents

# %%
# %%time
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
rouge_mean_embed, rouge_median_embed, rouge_std_embed = report_rouge_scores(articles, references, titles, 
                                                                            rouge_embed=True, methods=methods)

index =  ['1-gram F1', '1-gram Precision', '1-gram Recall', 'bi-gram F1', 'bi-gram Precision', 'bi-gram Recall', 
          'longest common F1', 'longest common Precision', 'longest common Recall', 'runtime', 'word count']

print('=' * 22 + ' Mean ' + '=' * 22)
rouge_mean_embed.index = index
display(rouge_mean_embed)

print('=' * 21 + ' Median ' + '=' * 21)
rouge_median_embed.index = index
display(rouge_median_embed)

print('=' * 15 + ' Standard Deviation ' + '=' * 15)
rouge_std_embed.index = index
display(rouge_std_embed)
