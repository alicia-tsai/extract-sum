# %%
import sys
sys.path.append('../src')

import numpy as np
import pandas as pd
import data
import utils
from main import extract_summary, report_rouge_scores

# %load_ext autoreload
# %autoreload 2
# Out:
# /usr/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.2) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ## Summarization

# %%
# Get list of titles, reference summaries, and body text
source_titles, source_refs, source_text = data.get_dailymail_data(50)
print(len(source_text))
# Out:
# 50

# %%
doc_idx = 2
doc = source_text[doc_idx]
ref = source_refs[doc_idx]
title = source_titles[doc_idx] if source_titles else None

# %%
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
extract_summary(doc, ref, title, report_rouge=False, methods=methods, print_summary=True);
# Out:
# Soruce Text: 22 sentences, 212 distinct vocab
# # of selected sentences: 2
# =============== Referecne Text ==============
# gary mckinnon's family battling against his extradition after he hacked into nasa and pentagon. doctors warned aspergers sufferer could kill himself if extradited to the u.s.
# -----
# Word count:26
#
# ========== Extracted summary: First k ==========
# By .
# Michael seamark.
# -----
# Word count:4
# First_k selection computation time: 0.000
#
# ========== Extracted summary: SMRS ==========
# Updated:.
# Michael seamark.
# -----
# Word count:3
# SMRS computation time: 0.501
#
# ========== Extracted summary: TextRank ==========
# mrs sharp will be handing in poems at downing street received after gary's supporters set up the poetic justice campaign marking his ten years of'fear and torment.'.
# mrs sharp, who will be joined by long-time supporter trudie styler, gary's mp david burrowes, former tory shadow home secretary david davis and lord maginnis said: 'in march david cameron is visiting president obama to discuss our “ special relationship”.
# Word count: 67
# TextRank computation time: 0.006
#
# ========== Extracted summary: FWSR-BM25 ==========
# Mrs sharp, who will be joined by long-time supporter trudie styler, gary's mp david burrowes, former tory shadow home secretary david davis and lord maginnis said: 'in march david cameron is visiting president obama to discuss our “ special relationship”.
# Scores of celebrities and politicians from all parties have voiced their support for gary since the daily mail launched its an affront to british justice campaign to stop his extradition in 2009. rock stars sir bob geldof, pink floyd's david gilmour, sting, singers chrissie hynde and peter gabriel and actress julie christie all voiced their support to keep gary in this country.
# -----
# Word count:102
# FWSR-BM25 computation time: 0.002
#
# ====== Extracted summary: FWSR-SIF ======
# Sentence embedding shape: (20, 300)
# By .
# His family have been battling against extradition after the asperger's sufferer hacked into nasa and pentagon computers looking for evidence of aliens.
# -----
# Word count:24
# FWSR-SIF computation time: 0.001

# %% [markdown]
# ### ROUGE Score

# %%
# %%time
# k=5
# ratio=0.3
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
extract_summary(doc, ref, title, report_rouge=True, rouge_embed=False, 
                methods=methods, print_summary=False, print_rouge=True);
# Out:
# =============== ROUGE Scores ===============
#
# first-k
# Overlap 1-gram 			F1: 0.000
# Overlap 1-gram 			Precision: 0.000
# Overlap 1-gram 			Recall: 0.000
# Overlap bi-gram 		F1: 0.000
# Overlap bi-gram 		Precision: 0.000
# Overlap bi-gram 		Recall: 0.000
# Longest Common Subsequence 	F1: 0.000
# Longest Common Subsequence 	Precision: 0.000
# Longest Common Subsequence 	Recall: 0.000
#
# SMRS
# Overlap 1-gram 			F1: 0.000
# Overlap 1-gram 			Precision: 0.000
# Overlap 1-gram 			Recall: 0.000
# Overlap bi-gram 		F1: 0.000
# Overlap bi-gram 		Precision: 0.000
# Overlap bi-gram 		Recall: 0.000
# Longest Common Subsequence 	F1: 0.000
# Longest Common Subsequence 	Precision: 0.000
# Longest Common Subsequence 	Recall: 0.000
#
# TextRank
# Overlap 1-gram 			F1: 0.114
# Overlap 1-gram 			Precision: 0.082
# Overlap 1-gram 			Recall: 0.185
# Overlap bi-gram 		F1: 0.000
# Overlap bi-gram 		Precision: 0.000
# Overlap bi-gram 		Recall: 0.000
# Longest Common Subsequence 	F1: 0.072
# Longest Common Subsequence 	Precision: 0.066
# Longest Common Subsequence 	Recall: 0.148
#
# FWSR-BM25
# Overlap 1-gram 			F1: 0.105
# Overlap 1-gram 			Precision: 0.069
# Overlap 1-gram 			Recall: 0.222
# Overlap bi-gram 		F1: 0.016
# Overlap bi-gram 		Precision: 0.010
# Overlap bi-gram 		Recall: 0.038
# Longest Common Subsequence 	F1: 0.073
# Longest Common Subsequence 	Precision: 0.069
# Longest Common Subsequence 	Recall: 0.222
#
# FWSR-SIF
# Overlap 1-gram 			F1: 0.480
# Overlap 1-gram 			Precision: 0.522
# Overlap 1-gram 			Recall: 0.444
# Overlap bi-gram 		F1: 0.250
# Overlap bi-gram 		Precision: 0.273
# Overlap bi-gram 		Recall: 0.231
# Longest Common Subsequence 	F1: 0.434
# Longest Common Subsequence 	Precision: 0.478
# Longest Common Subsequence 	Recall: 0.407
# CPU times: user 7.41 s, sys: 1.09 s, total: 8.5 s
# Wall time: 12.7 s

# %% [markdown]
# ### Word Embedding ROUGE Score

# %%
# %%time
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
_ = extract_summary(doc, ref, title, report_rouge=True, rouge_embed=True, 
                    methods=methods, print_summary=False, print_rouge=True);
# Out:
# =============== ROUGE Scores ===============
#
# first-k
# Overlap 1-gram 			F1: 0.529
# Overlap 1-gram 			Precision: 0.454
# Overlap 1-gram 			Recall: 0.634
# Overlap bi-gram 		F1: 0.627
# Overlap bi-gram 		Precision: 0.541
# Overlap bi-gram 		Recall: 0.744
# Longest Common Subsequence 	F1: 0.289
# Longest Common Subsequence 	Precision: 0.264
# Longest Common Subsequence 	Recall: 0.634
#
# SMRS
# Overlap 1-gram 			F1: 0.333
# Overlap 1-gram 			Precision: 0.311
# Overlap 1-gram 			Recall: 0.358
# Overlap bi-gram 		F1: 0.497
# Overlap bi-gram 		Precision: 0.489
# Overlap bi-gram 		Recall: 0.505
# Longest Common Subsequence 	F1: 0.274
# Longest Common Subsequence 	Precision: 0.247
# Longest Common Subsequence 	Recall: 0.358
#
# TextRank
# Overlap 1-gram 			F1: 0.541
# Overlap 1-gram 			Precision: 0.471
# Overlap 1-gram 			Recall: 0.634
# Overlap bi-gram 		F1: 0.635
# Overlap bi-gram 		Precision: 0.546
# Overlap bi-gram 		Recall: 0.759
# Longest Common Subsequence 	F1: 0.254
# Longest Common Subsequence 	Precision: 0.235
# Longest Common Subsequence 	Recall: 0.634
#
# FWSR-BM25
# Overlap 1-gram 			F1: 0.496
# Overlap 1-gram 			Precision: 0.430
# Overlap 1-gram 			Recall: 0.586
# Overlap bi-gram 		F1: 0.590
# Overlap bi-gram 		Precision: 0.497
# Overlap bi-gram 		Recall: 0.725
# Longest Common Subsequence 	F1: 0.195
# Longest Common Subsequence 	Precision: 0.183
# Longest Common Subsequence 	Recall: 0.586
#
# FWSR-SIF
# Overlap 1-gram 			F1: 0.441
# Overlap 1-gram 			Precision: 0.460
# Overlap 1-gram 			Recall: 0.424
# Overlap bi-gram 		F1: 0.562
# Overlap bi-gram 		Precision: 0.562
# Overlap bi-gram 		Recall: 0.561
# Longest Common Subsequence 	F1: 0.391
# Longest Common Subsequence 	Precision: 0.369
# Longest Common Subsequence 	Recall: 0.424
# CPU times: user 1min 50s, sys: 5.15 s, total: 1min 55s
# Wall time: 1min 58s

# %% [markdown]
# ## ROUGE Score Across Documents

# %%
#k = 5
start = 0
num_articles = 50
#articles = source_text[start : start + num_articles]
#references = source_refs[start : start + num_articles]
#titles = source_titles[start : start + num_articles] if source_titles else None

# %%
# %%time
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
rouge_mean, rouge_median, rouge_std = report_rouge_scores(source_text[start : start + num_articles], 
                                                          source_refs[start : start + num_articles], 
                                                          methods=methods)#, ratio=0.1)

index =  ['1-gram F1', '1-gram Precision', '1-gram Recall', 'bi-gram F1', 'bi-gram Precision', 'bi-gram Recall', 
          'longest common F1', 'longest common Precision', 'longest common Recall', 'runtime', 'word count']

print('=' * 22 + ' Mean ' + '=' * 22)
rouge_mean.index = index
display(rouge_mean)

print('=' * 21 + ' Median ' + '=' * 21)
rouge_median.index = index
display(rouge_median)

print('=' * 15 + ' Standard Deviation ' + '=' * 15)
rouge_std.index = index
display(rouge_std)
# Out:
# ====================== Mean ======================
#                             first-k       SMRS   TextRank   FWSR-BM25  \
# 1-gram F1                  0.304785   0.117730   0.320968    0.292462
# 1-gram Precision           0.266864   0.131922   0.294317    0.231640
# 1-gram Recall              0.372898   0.121775   0.373949    0.417601
# bi-gram F1                 0.128468   0.023739   0.106344    0.096875
# bi-gram Precision          0.111552   0.024946   0.096878    0.075644
# bi-gram Recall             0.160728   0.025988   0.129272    0.144758
# longest common F1          0.263164   0.100604   0.272610    0.225467
# longest common Precision   0.247856   0.125156   0.266190    0.206642
# longest common Recall      0.346707   0.112868   0.337578    0.374716
# runtime                    0.000002   0.459653   0.008345    0.000623
# word count                74.420000  44.180000  84.840000  106.240000
#
#                            FWSR-SIF
# 1-gram F1                  0.242443
# 1-gram Precision           0.248089
# 1-gram Recall              0.272913
# bi-gram F1                 0.091983
# bi-gram Precision          0.099041
# bi-gram Recall             0.102381
# longest common F1          0.201941
# longest common Precision   0.223700
# longest common Recall      0.250749
# runtime                    0.159634
# word count                57.680000
# ===================== Median =====================
#                             first-k       SMRS   TextRank   FWSR-BM25  \
# 1-gram F1                  0.350024   0.112461   0.327055    0.294208
# 1-gram Precision           0.304206   0.126136   0.274917    0.226312
# 1-gram Recall              0.413942   0.092330   0.387223    0.433798
# bi-gram F1                 0.115422   0.000000   0.102802    0.084741
# bi-gram Precision          0.089144   0.000000   0.084279    0.062114
# bi-gram Recall             0.146429   0.000000   0.133333    0.134568
# longest common F1          0.306579   0.100841   0.263752    0.229566
# longest common Precision   0.289411   0.121728   0.242311    0.209594
# longest common Recall      0.403390   0.092330   0.346429    0.383484
# runtime                    0.000002   0.467866   0.006768    0.000564
# word count                77.000000  32.500000  81.000000  105.500000
#
#                            FWSR-SIF
# 1-gram F1                  0.250214
# 1-gram Precision           0.227955
# 1-gram Recall              0.309311
# bi-gram F1                 0.054983
# bi-gram Precision          0.065903
# bi-gram Recall             0.064334
# longest common F1          0.194734
# longest common Precision   0.215931
# longest common Recall      0.278125
# runtime                    0.000854
# word count                55.000000
# =============== Standard Deviation ===============
#                                first-k       SMRS   TextRank  FWSR-BM25  \
# 1-gram F1                 1.872140e-01   0.087769   0.113948   0.100920
# 1-gram Precision          1.690986e-01   0.085646   0.122660   0.082507
# 1-gram Recall             2.316896e-01   0.107310   0.137107   0.148766
# bi-gram F1                1.223738e-01   0.043516   0.069198   0.067180
# bi-gram Precision         1.183410e-01   0.048667   0.074750   0.054697
# bi-gram Recall            1.401771e-01   0.049976   0.079046   0.096380
# longest common F1         1.711467e-01   0.076859   0.109045   0.085643
# longest common Precision  1.620402e-01   0.081211   0.117569   0.074989
# longest common Recall     2.202495e-01   0.095576   0.131560   0.140398
# runtime                   3.162980e-07   0.072434   0.004718   0.000293
# word count                4.764246e+01  35.227654  41.399208  46.041529
#
#                            FWSR-SIF
# 1-gram F1                  0.150805
# 1-gram Precision           0.175939
# 1-gram Recall              0.180808
# bi-gram F1                 0.105086
# bi-gram Precision          0.139985
# bi-gram Recall             0.110686
# longest common F1          0.138199
# longest common Precision   0.166192
# longest common Recall      0.173933
# runtime                    0.375264
# word count                37.855219
# CPU times: user 6min 15s, sys: 27.6 s, total: 6min 43s
# Wall time: 9min 32s

# %%
rouge_mean.to_csv('dailymail_lexical_rouge_mean_50.csv', index=False)
rouge_median.to_csv('dailymail_lexical_rouge_median_50.csv', index=False)
rouge_std.to_csv('dailymail_lexical_rouge_std_50.csv', index=False)

# %% [markdown]
# ### Word Embedding ROUGE Score Across Documents

# %%
# %%time
methods = ['first-k', 'SMRS', 'TextRank', 'FWSR-BM25', 'FWSR-SIF']
rouge_mean_embed, rouge_median_embed, rouge_std_embed = report_rouge_scores(articles, references, titles, 
                                                                            rouge_embed=True, methods=methods)

index =  ['1-gram F1', '1-gram Precision', '1-gram Recall', 'bi-gram F1', 'bi-gram Precision', 'bi-gram Recall', 
          'longest common F1', 'longest common Precision', 'longest common Recall', 'runtime', 'word count']

print('=' * 22 + ' Mean ' + '=' * 22)
rouge_mean_embed.index = index
display(rouge_mean_embed)

print('=' * 21 + ' Median ' + '=' * 21)
rouge_median_embed.index = index
display(rouge_median_embed)

print('=' * 15 + ' Standard Deviation ' + '=' * 15)
rouge_std_embed.index = index
display(rouge_std_embed)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/GitHub/extract-sum/src/main.py in report_rouge_scores(docs, refs, titles, k, ratio, rouge_embed, methods)
#     120         results = extract_summary(doc, ref, title, k=k, ratio=ratio,
#     121                                         print_summary=False, report_rouge=True, print_rouge=False,
# --> 122                                         rouge_embed=rouge_embed, vectorize_scores=True, methods=methods)  # summary text won't be printed
#     123         if results is not None:
#     124             summary, word_count, runtime, scores = results
#
# ~/GitHub/extract-sum/src/main.py in extract_summary(doc, ref, title, k, ratio, print_summary, report_rouge, print_rouge, rouge_embed, vectorize_scores, methods)
#     105             if print_rouge: print('\n' + method)
#     106             if rouge_embed:
# --> 107                 scores[method] = utils.get_rouge_score(summary[method], ref, print_rouge, vectorize_scores, rouge_embed=True)
#     108             else:
#     109                 scores[method] = utils.get_rouge_score(summary[method], ref, print_rouge, vectorize_scores)
#
# ~/GitHub/extract-sum/src/utils.py in get_rouge_score(summary, reference, verbose, vectorize, rouge_embed, embed_dict)
#     181 def get_rouge_score(summary, reference, verbose=True, vectorize=False, rouge_embed=False, embed_dict=None):
#     182     rouge = Rouge()
# --> 183     scores = rouge.get_scores(summary, reference, avg=True, rouge_embed=rouge_embed, embed_dict=embed_dict)
#     184     if verbose:
#     185         print('Overlap 1-gram \t\t\tF1: %.3f' %(scores['rouge-1']['f']))
#
# ~/GitHub/extract-sum/src/rouge_scores.py in get_scores(self, hyps, refs, avg, ignore_empty, rouge_embed, embed_dict)
#     425         if not avg:
#     426             return self._get_scores(hyps, refs, rouge_embed, embed_dict)
# --> 427         return self._get_avg_scores(hyps, refs, rouge_embed, embed_dict)
#     428
#     429     def _get_scores(self, hyps, refs, rouge_embed, embed_dict):
#
# ~/GitHub/extract-sum/src/rouge_scores.py in _get_avg_scores(self, hyps, refs, rouge_embed, embed_dict)
#     454             for m in self.metrics:
#     455                 fn = Rouge.AVAILABLE_METRICS[m]
# --> 456                 sc = fn(hyp, ref, rouge_embed, embed_dict)
#     457                 scores[m] = {s: scores[m][s] + sc[s] for s in self.stats}
#     458             count += 1
#
# ~/GitHub/extract-sum/src/rouge_scores.py in <lambda>(hyp, ref, rouge_embed, embed_dict)
#     384     DEFAULT_METRICS = ["rouge-1", "rouge-2", "rouge-l"]
#     385     AVAILABLE_METRICS = {
# --> 386         "rouge-1": lambda hyp, ref, rouge_embed, embed_dict: rouge_n(hyp, ref, 1, rouge_embed, embed_dict),
#     387         "rouge-2": lambda hyp, ref, rouge_embed, embed_dict: rouge_n(hyp, ref, 2, rouge_embed, embed_dict),
#     388         "rouge-l": lambda hyp, ref, rouge_embed, embed_dict: rouge_l_summary_level(hyp, ref, rouge_embed, embed_dict),
#
# ~/GitHub/extract-sum/src/rouge_scores.py in rouge_n(evaluated_sentences, reference_sentences, n, embed, embed_dict)
#     171
#     172     if embed:
# --> 173         return f_r_p_rouge_n_embed(evaluated_count, reference_count, evaluated_ngrams, reference_ngrams, embed_dict)
#     174     else:
#     175         # Gets the overlapping ngrams between evaluated and reference
#
# ~/GitHub/extract-sum/src/rouge_scores.py in f_r_p_rouge_n_embed(evaluated_count, reference_count, evaluated_ngrams, reference_ngrams, embed_dict)
#     184         nlp = spacy.load(embed_dict)
#     185     else:
# --> 186         nlp = spacy.load('en_core_web_lg')
#     187     stop_words = stopwords.words('english')
#     188
#
# /usr/lib/python3.7/site-packages/spacy/__init__.py in load(name, **overrides)
#      19     if depr_path not in (True, False, None):
#      20         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 21     return util.load_model(name, **overrides)
#      22
#      23
#
# /usr/lib/python3.7/site-packages/spacy/util.py in load_model(name, **overrides)
#     110     if isinstance(name, basestring_):  # in data dir / shortcut
#     111         if name in set([d.name for d in data_path.iterdir()]):
# --> 112             return load_model_from_link(name, **overrides)
#     113         if is_package(name):  # installed as package
#     114             return load_model_from_package(name, **overrides)
#
# /usr/lib/python3.7/site-packages/spacy/util.py in load_model_from_link(name, **overrides)
#     127     except AttributeError:
#     128         raise IOError(Errors.E051.format(name=name))
# --> 129     return cls.load(**overrides)
#     130
#     131
#
# /usr/lib/python3.7/site-packages/spacy/data/en_core_web_lg/__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# /usr/lib/python3.7/site-packages/spacy/util.py in load_model_from_init_py(init_file, **overrides)
#     171     if not model_path.exists():
#     172         raise IOError(Errors.E052.format(path=path2str(data_path)))
# --> 173     return load_model_from_path(data_path, meta, **overrides)
#     174
#     175
#
# /usr/lib/python3.7/site-packages/spacy/util.py in load_model_from_path(model_path, meta, **overrides)
#     154             component = nlp.create_pipe(name, config=config)
#     155             nlp.add_pipe(component, name=name)
# --> 156     return nlp.from_disk(model_path)
#     157
#     158
#
# /usr/lib/python3.7/site-packages/spacy/language.py in from_disk(self, path, disable)
#     645         if not (path / 'vocab').exists():
#     646             exclude['vocab'] = True
# --> 647         util.from_disk(path, deserializers, exclude)
#     648         self._path = path
#     649         return self
#
# /usr/lib/python3.7/site-packages/spacy/util.py in from_disk(path, readers, exclude)
#     509     for key, reader in readers.items():
#     510         if key not in exclude:
# --> 511             reader(path / key)
#     512     return path
#     513
#
# /usr/lib/python3.7/site-packages/spacy/language.py in <lambda>(p)
#     633             ('meta.json', lambda p: self.meta.update(util.read_json(p))),
#     634             ('vocab', lambda p: (
# --> 635                 self.vocab.from_disk(p) and _fix_pretrained_vectors_name(self))),
#     636             ('tokenizer', lambda p: self.tokenizer.from_disk(p, vocab=False)),
#     637         ))
#
# vocab.pyx in spacy.vocab.Vocab.from_disk()
#
# /usr/lib/python3.7/pathlib.py in __truediv__(self, key)
#     898         return self._make_child(args)
#     899
# --> 900     def __truediv__(self, key):
#     901         return self._make_child((key,))
#     902
#
# KeyboardInterrupt:

# %%
rouge_mean.to_csv('cnn_semantic_rouge_mean_50.csv', index=False)
rouge_median.to_csv('cnn_semantic_rouge_median_50.csv', index=False)
rouge_std.to_csv('cnn_semantic_rouge_std_50.csv', index=False)

# %% [markdown]
# ## Data

# %%
references[3]
# Out:
# 'chicago wins bid for new george lucas museum. mayor rahm emanuel calls it "a milestone" for his city. lucas says a prime location in chicago was a deciding factor. museum will house lucas\' art collection and movie memorabilia.'
